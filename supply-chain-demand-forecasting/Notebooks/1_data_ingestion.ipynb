# %%
# 1_data_ingestion.ipynb

import pandas as pd

# Load your sales dataset (replace with your actual path)
file_path = "supply_chain_dataset.csv"
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#          date Product type      SKU   Price  Availability  \
# 0  2022-01-01    Furniture  SKU_001  408.44      In Stock
# 1  2022-01-01     Clothing  SKU_002   53.18      In Stock
# 2  2022-01-01  Electronics  SKU_003  153.90  Out of Stock
# 3  2022-01-01     Clothing  SKU_004  377.27      In Stock
# 4  2022-01-01  Electronics  SKU_005  139.42  Out of Stock
#
#    Number of products sold  Revenue generated Customer demographics  \
# 0                       12            4901.28                Senior
# 1                        8             425.44                 Adult
# 2                        9            1385.10                 Youth
# 3                        5            1886.35                 Youth
# 4                       14            1951.88                 Youth
#
#    Stock levels  Lead times  ...  Location  Lead time Production volumes  \
# 0           121           4  ...     South          6                819
# ...
